# %% [markdown]
# # SBA

# %% [markdown]
# ## SECTION 1

# %% [markdown]
# ## Task 1: Read Data From the 'woocommerce-product-export.csv'

# %%
# import all required libraries
import pandas as pd                         # uses for load data, clean data, analysis data
from pathlib import Path                    # uses for handling file path
import matplotlib.pyplot as plt             # use to create visualization such as plot scatter chart, bar chart, hstogram chart, line chart

# %%
# create file path
woocommerce_data = Path("woocommerce-product-export.csv")       # create a file path
data = pd.read_csv(woocommerce_data)                            # load the csv data

# %%
# check if file exist
file_path = Path("woocommerce-product-export.csv") 
if file_path.is_file():
    print("File Exist - file is loading...")
    data = pd.read_csv(woocommerce_data)   
else: 
    print("No File Exists - Check file name or file path.")
# Out:
# File Exist - file is loading...

# %%
# load the file in to the DataFrame
df = pd.DataFrame(data)

# %% [markdown]
# ## Task 2: Show a concise summary of the columns

# %%
# Summary information gives the columns information such as columns data type, non null count and columns name 
print("Columns Information")
print(df.info())
# Out:
# Columns Information
# <class 'pandas.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   month_number  12 non-null     int64
#  1   facecream     12 non-null     int64
#  2   facewash      12 non-null     int64
#  3   toothpaste    12 non-null     int64
#  4   bathingsoap   12 non-null     int64
#  5   shampoo       12 non-null     int64
#  6   moisturizer   12 non-null     int64
#  7   total_units   12 non-null     int64
#  8   total_profit  12 non-null     int64
# dtypes: int64(9)
# memory usage: 996.0 bytes
# None

# %% [markdown]
# ## Task 3: Summary of Statistics

# %%
# df.describe() --> gives numeric descriptive statistics such as count, mean, std, min, max, and percentiles
# df.describe(include="object") --> gives categorical descriptive statistics such as count, unique values, most frequent value...

print("Numeric Descriptive Statistics:")
print(df.describe())                    # numeric descriptive statistics
# Out:
# Numeric Descriptive Statistics:
#        month_number    facecream     facewash   toothpaste   bathingsoap  \
# count     12.000000    12.000000    12.000000    12.000000     12.000000
# mean       6.500000  2873.333333  1542.916667  5825.833333   9500.833333
# std        3.605551   584.595172   316.733745  1242.032486   2348.095779
# min        1.000000  1990.000000  1120.000000  4550.000000   6100.000000
# 25%        3.750000  2460.000000  1305.000000  4862.500000   8015.000000
# 50%        6.500000  2830.000000  1527.500000  5530.000000   9090.000000
# 75%        9.250000  3435.000000  1765.000000  6400.000000  10045.000000
# max       12.000000  3700.000000  2100.000000  8300.000000  14400.000000
#
#            shampoo  moisturizer  total_units   total_profit
# count    12.000000    12.000000     12.00000      12.000000
# mean   2117.500000  1542.916667  26027.50000  260275.000000
# std     617.724931   316.733745   7014.36594   70143.659404
# ...

# %% [markdown]
# ## Task 4: Print the First Five Rows

# %%
# print the first five rows of data to check the datas and columns
print("First 5 Rows of Data in The DataFrame:")
print(df.head())
# Out:
# First 5 Rows of Data in The DataFrame:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %% [markdown]
# ## Task 5: Print the Last Five Rows of Data

# %%
# print the last five rows of data to check the datas and columns
print("Last 5 Rows of Data in The DataFrame:")
print(df.tail())
# Out:
# Last 5 Rows of Data in The DataFrame:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %% [markdown]
# ## Print  the "total_profit" and “month_number” columns only

# %%
#print only selected columns to inspect
print("Display Selected Columns:")
print(df[["total_profit", "month_number"]])
# Out:
# Display Selected Columns:
#     total_profit  month_number
# 0         211000             1
# 1         183300             2
# 2         224700             3
# 3         222700             4
# 4         209600             5
# 5         201400             6
# 6         295500             7
# 7         361400             8
# 8         234000             9
# 9         266700            10
# 10        412800            11
# 11        300200            12

# %% [markdown]
# ## Task 7: Read the total profit of all months and show it using the Bar plot.

# %%
# We visualize the company profit per month
# generated using a bar chart.
#
# df.month_number
#     Provides the month number for the x-axis.
#
# df.total_profit
#     Provides the total profit values for the height of each bar.

import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.bar(df.month_number, df.total_profit)

plt.title("Company profit per month")
plt.xlabel("Month Number")
plt.ylabel("Total Profit")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Task 8: Read the total profit of all of the months

# %%
# We visualize the company profit per month
# generated using a line chart.
#
# df.month_number
#     Provides the month number for the x-axis.
#
# df.total_profit
#     Provides the total profit values for the height of each bar.

import matplotlib.pyplot as plt
x = df.month_number
y = df.total_profit

plt.title("Company profit per month")
plt.xlabel("Month Number")
plt.ylabel("Toatl Profit")

# Set plot colors and market
plt.plot(x, y, marker = 'o', markerfacecolor='black', linestyle='--', color="red", linewidth=3, label="Profit data of last year" )

# Enabling grid lines:
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## Task 9: Print all of the product sales data

# %%
# visualize all of the product sales data using a line chart.

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
plt.plot(df.month_number, df.facecream, '-', color='blue', marker="o", label="Face Cream Sales Data")
plt.plot(df.month_number, df.facewash, '-.', color='orange', marker="o", label="Face Wash Sales Data")
plt.plot(df.month_number, df.toothpaste, '-', color='green', marker="o", label="ToothPaste Sales Data")  # Plot job rate data
plt.plot(df.month_number, df.bathingsoap, '-', color='red', marker="o", label="Bathingsoap Sales Data")
plt.plot(df.month_number, df.shampoo, '-', color='purple', marker="o", label="Sahmpoo Sales Data")
plt.plot(df.month_number, df.moisturizer, '-', color='brown', marker="o", label="Moisturizer Sales Data")

plt.ylabel("Sales units in number")
plt.xlabel("Month Number")
plt.title("Sales Data")
plt.legend()

plt.show()

# %% [markdown]
# ## Task 10: Read “bathingsoap” sales data for each month

# %%
# visualize bathingsoap sales data for each month using a schatter chart.
#
# df.month_number
#     Provides the month number for the x-axis.
#
# df.bathingsoap
#     number of unit sold for y axis.
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.scatter(df.month_number, df.bathingsoap, label="Bathingsoap Sales Data")

plt.ylabel("Number of Unit Sold")
plt.xlabel("Month Number")
plt.title("bathingsoap Sales data")

plt.grid(linestyle='--')
plt.legend()
plt.show()

# %% [markdown]
# ## SECTION 2

# %% [markdown]
# ### Task 1: Line chart of date vs temperature

# %%
# visualize date vs temperature using a line chart.
#
# date:
#     Provides the date for the x-axis.
#
# temp:
#     Provides the temperature values.
date=["25/12","26/12","27/12"]
temp=[8.5,10.5,6.8]

# Set plot colors and market
plt.plot(date, temp, marker = 'o', linestyle='--', color="blue")
plt.title("Date-wise Temperature")
plt.xlabel("Date")
plt.ylabel("Temperature")
plt.show()

# %% [markdown]
# ## Task 2: Average weight against the average height

# %%
# visualize the average weight againist the average height using line chart.
#
# height
#     Provides the height number for the x-axis.
#
# weight
#     Provides the weight values for the y-axis.

height=[121.9,124.5,129.5,134.6,139.7,147.3,152.4,157.5,162.6]
weight=[19.7,21.3,23.5,25.9,28.5,32.1,35.7,39.6,43.2]

# Set plot colors and market
plt.plot(weight, height, marker = 'o', ms= 10, lw=3, linestyle='dashdot', color="green")
plt.title("Average weight with respect to average height")
plt.xlabel("Weight in kg")
plt.ylabel("Height in cm")
plt.show()
